# %%
import os
from datetime import datetime

import boto3
from sagemaker import analytics, image_uris
from sagemaker.pytorch import PyTorch
from sagemaker import get_execution_role
from sagemaker.debugger import (
    Rule,
    DebuggerHookConfig,
    TensorBoardOutputConfig,
    CollectionConfig,
    ProfilerConfig,
    FrameworkProfile,
    DetailedProfilingConfig,
    rule_configs,
    ProfilerRule,
)
from smdebug.core.collection import CollectionKeys

# %%
#import sagemaker
#import botocore

# %%
#!pip install --upgrade sagemaker boto3 botocore

# %%
profiler_config=ProfilerConfig(
    system_monitor_interval_millis=500,
)

# %%
os.environ['AWS_DEFAULT_REGION']= 'us-west-2'

# %%
time_str = datetime.now().strftime("%d-%m-%Y-%H-%M-%S")

region = boto3.session.Session().region_name
boto_sess = boto3.Session()
sm = boto_sess.client('sagemaker')

s3_bucket = "s3://jbsnyder-sagemaker-us-west-2/"

base_job_name = "openclip-scaling"
date_str = datetime.now().strftime("%d-%m-%Y")
time_str = datetime.now().strftime("%d-%m-%Y-%H-%M-%S")
job_name = f"{base_job_name}-{time_str}"

output_path = os.path.join(s3_bucket, "sagemaker-output", date_str, job_name)
code_location = os.path.join(s3_bucket, "sagemaker-code", date_str, job_name)

# %%
nodes = 4
batch_size = 512
global_batch_size = batch_size * nodes * 8
samples_per_epoch = global_batch_size * 1000
epochs = 50
lr = 1e-4/4096*global_batch_size

# %%
hyperparameters = {"train-data": "\"pipe:aws s3 cp s3://jbsnyder-sagemaker-us-west-2/data/laion/laion400m/data/{00000..02499}.tar -\"", 
                   "train-num-samples": samples_per_epoch, 
                   "val-data": "\"pipe:aws s3 cp s3://jbsnyder-sagemaker-us-west-2/data/laion/laion400m/data/{02500..02587}.tar -\"",
                   "val-num-samples": 10000,
                   "batch-size": batch_size,
                   "warmup": 2000,
                   "epochs": epochs,
                   "lr": lr,
                   "wd": 0.2,
                   "precision": "amp",
                   "workers": 4,
                   "log-every-n-steps": 100,
                   "log-path": "/opt/ml/checkpoints/logs/",
                   "dist-backend": "smddp"
                   }

distribution = { "smdistributed": { "dataparallel": { "enabled": True } } }
entry_point = "sm_train.py"

# %%
instance_type = 'ml.p4d.24xlarge'

image_uri = "920076894685.dkr.ecr.us-west-2.amazonaws.com/jbsnyder:open-clip-sm"

# %%
estimator = PyTorch(
    source_dir="./src",
    entry_point=entry_point,
    base_job_name=job_name,
    role=get_execution_role(),
    instance_count=nodes,
    instance_type=instance_type,
    distribution=distribution,
    max_run=36000,
    hyperparameters=hyperparameters,
    image_uri=image_uri,
    output_path=os.path.join(output_path, 'training-output'),
    checkpoint_s3_uri=os.path.join(output_path, 'training-checkpoints'),
    model_dir=os.path.join(output_path, 'training-model'),
    code_location=code_location,
    profiler_config=profiler_config,
    debugger_hook_config=False
)

# %%
estimator.fit(
    inputs=None,
    wait=False,
    job_name=job_name,
)
# Out:
# INFO:sagemaker:Creating training-job with name: openclip-scaling-24-01-2023-21-17-32

# %%
estimator.logs()
# Out:
# 2023-01-24 21:17:35 Starting - Starting the training job......
# 2023-01-24 21:18:18 Starting - Preparing the instances for training..............................
# 2023-01-24 21:23:38 Downloading - Downloading input data...
# 2023-01-24 21:23:48 Training - Downloading the training image...........................
# 2023-01-24 21:28:30 Training - Training image download completed. Training in progress.bash: cannot set terminal process group (-1): Inappropriate ioctl for device
# bash: no job control in this shell
# 2023-01-24 21:28:33,354 sagemaker-training-toolkit INFO     Imported framework sagemaker_pytorch_container.training
# 2023-01-24 21:28:33,425 sagemaker-training-toolkit INFO     No Neurons detected (normal if no neurons installed)
# 2023-01-24 21:28:33,435 sagemaker_pytorch_container.training INFO     Block until all host DNS lookups succeed.
# 2023-01-24 21:28:33,442 sagemaker_pytorch_container.training INFO     Invoking SMDataParallel
# 2023-01-24 21:28:33,442 sagemaker_pytorch_container.training INFO     Invoking user training script.
# 2023-01-24 21:28:34,185 sagemaker-training-toolkit INFO     No Neurons detected (normal if no neurons installed)
# 2023-01-24 21:28:34,266 sagemaker-training-toolkit INFO     No Neurons detected (normal if no neurons installed)
# 2023-01-24 21:28:34,276 sagemaker-training-toolkit INFO     Starting MPI run as worker node.
# 2023-01-24 21:28:34,276 sagemaker-training-toolkit INFO     Waiting for MPI Master to create SSH daemon.
# 2023-01-24 21:28:34,285 sagemaker-training-toolkit INFO     Cannot connect to host algo-4
# 2023-01-24 21:28:34,285 sagemaker-training-toolkit INFO     Connection failed with exception:
#  [Errno None] Unable to connect to port 22 on 10.0.81.60.              Can be ignored for worker when master completes and exits.
# 2023-01-24 21:28:35,296 paramiko.transport INFO     Connected (version 2.0, client OpenSSH_8.2p1)
# 2023-01-24 21:28:35,354 paramiko.transport INFO     Authentication (publickey) successful!
# 2023-01-24 21:28:35,355 sagemaker-training-toolkit INFO     Can connect to host algo-4
# 2023-01-24 21:28:35,355 sagemaker-training-toolkit INFO     MPI Master online, creating SSH daemon.
# 2023-01-24 21:28:35,355 sagemaker-training-toolkit INFO     Writing environment variables to /etc/environment for the MPI process.
# 2023-01-24 21:28:35,359 sagemaker-training-toolkit INFO     Waiting for MPI process to finish.
# bash: cannot set terminal process group (-1): Inappropriate ioctl for device
# bash: no job control in this shell
# 2023-01-24 21:28:33,374 sagemaker-training-toolkit INFO     Imported framework sagemaker_pytorch_container.training
# 2023-01-24 21:28:33,443 sagemaker-training-toolkit INFO     No Neurons detected (normal if no neurons installed)
# 2023-01-24 21:28:33,452 sagemaker_pytorch_container.training INFO     Block until all host DNS lookups succeed.
# 2023-01-24 21:28:33,458 sagemaker_pytorch_container.training INFO     Invoking SMDataParallel
# 2023-01-24 21:28:33,458 sagemaker_pytorch_container.training INFO     Invoking user training script.
# 2023-01-24 21:28:34,184 sagemaker-training-toolkit INFO     No Neurons detected (normal if no neurons installed)
# 2023-01-24 21:28:34,267 sagemaker-training-toolkit INFO     No Neurons detected (normal if no neurons installed)
# 2023-01-24 21:28:34,276 sagemaker-training-toolkit INFO     Starting MPI run as worker node.
# 2023-01-24 21:28:34,276 sagemaker-training-toolkit INFO     Waiting for MPI Master to create SSH daemon.
# 2023-01-24 21:28:34,286 sagemaker-training-toolkit INFO     Cannot connect to host algo-4
# 2023-01-24 21:28:34,286 sagemaker-training-toolkit INFO     Connection failed with exception:
#  [Errno None] Unable to connect to port 22 on 10.0.81.60.              Can be ignored for worker when master completes and exits.
# 2023-01-24 21:28:35,296 paramiko.transport INFO     Connected (version 2.0, client OpenSSH_8.2p1)
# 2023-01-24 21:28:35,355 paramiko.transport INFO     Authentication (publickey) successful!
# 2023-01-24 21:28:35,355 sagemaker-training-toolkit INFO     Can connect to host algo-4
# 2023-01-24 21:28:35,355 sagemaker-training-toolkit INFO     MPI Master online, creating SSH daemon.
# 2023-01-24 21:28:35,355 sagemaker-training-toolkit INFO     Writing environment variables to /etc/environment for the MPI process.
# 2023-01-24 21:28:35,360 sagemaker-training-toolkit INFO     Waiting for MPI process to finish.
# bash: cannot set terminal process group (-1): Inappropriate ioctl for device
# bash: no job control in this shell
# 2023-01-24 21:28:33,494 sagemaker-training-toolkit INFO     Imported framework sagemaker_pytorch_container.training
# 2023-01-24 21:28:33,567 sagemaker-training-toolkit INFO     No Neurons detected (normal if no neurons installed)
# 2023-01-24 21:28:33,576 sagemaker_pytorch_container.training INFO     Block until all host DNS lookups succeed.
# 2023-01-24 21:28:33,583 sagemaker_pytorch_container.training INFO     Invoking SMDataParallel
# 2023-01-24 21:28:33,583 sagemaker_pytorch_container.training INFO     Invoking user training script.
# 2023-01-24 21:28:34,296 sagemaker-training-toolkit INFO     No Neurons detected (normal if no neurons installed)
# 2023-01-24 21:28:34,377 sagemaker-training-toolkit INFO     No Neurons detected (normal if no neurons installed)
# 2023-01-24 21:28:34,386 sagemaker-training-toolkit INFO     Starting MPI run as worker node.
# 2023-01-24 21:28:34,387 sagemaker-training-toolkit INFO     Waiting for MPI Master to create SSH daemon.
# 2023-01-24 21:28:34,404 paramiko.transport INFO     Connected (version 2.0, client OpenSSH_8.2p1)
# 2023-01-24 21:28:34,501 paramiko.transport INFO     Authentication (publickey) successful!
# 2023-01-24 21:28:34,501 sagemaker-training-toolkit INFO     Can connect to host algo-4
# 2023-01-24 21:28:34,501 sagemaker-training-toolkit INFO     MPI Master online, creating SSH daemon.
# 2023-01-24 21:28:34,501 sagemaker-training-toolkit INFO     Writing environment variables to /etc/environment for the MPI process.
# 2023-01-24 21:28:34,506 sagemaker-training-toolkit INFO     Waiting for MPI process to finish.
# bash: cannot set terminal process group (-1): Inappropriate ioctl for device
# bash: no job control in this shell
# 2023-01-24 21:28:33,348 sagemaker-training-toolkit INFO     Imported framework sagemaker_pytorch_container.training
# 2023-01-24 21:28:33,417 sagemaker-training-toolkit INFO     No Neurons detected (normal if no neurons installed)
# 2023-01-24 21:28:33,426 sagemaker_pytorch_container.training INFO     Block until all host DNS lookups succeed.
# 2023-01-24 21:28:33,435 sagemaker_pytorch_container.training INFO     Invoking SMDataParallel
# 2023-01-24 21:28:33,435 sagemaker_pytorch_container.training INFO     Invoking user training script.
# 2023-01-24 21:28:34,193 sagemaker-training-toolkit INFO     No Neurons detected (normal if no neurons installed)
# 2023-01-24 21:28:34,275 sagemaker-training-toolkit INFO     No Neurons detected (normal if no neurons installed)
# 2023-01-24 21:28:34,285 sagemaker-training-toolkit INFO     Starting MPI run as worker node.
# 2023-01-24 21:28:34,285 sagemaker-training-toolkit INFO     Creating SSH daemon.
# 2023-01-24 21:28:34,288 sagemaker-training-toolkit INFO     Waiting for MPI workers to establish their SSH connections
# 2023-01-24 21:28:34,291 sagemaker-training-toolkit INFO     Cannot connect to host algo-2 at port 22. Retrying...
# 2023-01-24 21:28:34,291 sagemaker-training-toolkit INFO     Connection closed
# 2023-01-24 21:28:35,294 sagemaker-training-toolkit INFO     Cannot connect to host algo-2 at port 22. Retrying...
# 2023-01-24 21:28:35,294 sagemaker-training-toolkit INFO     Connection closed
# 2023-01-24 21:28:36,303 paramiko.transport INFO     Connected (version 2.0, client OpenSSH_8.2p1)
# 2023-01-24 21:28:36,379 paramiko.transport INFO     Authentication (publickey) successful!
# 2023-01-24 21:28:36,379 sagemaker-training-toolkit INFO     Can connect to host algo-2 at port 22
# 2023-01-24 21:28:36,379 sagemaker-training-toolkit INFO     Connection closed
# 2023-01-24 21:28:36,379 sagemaker-training-toolkit INFO     Worker algo-2 available for communication
# 2023-01-24 21:28:36,389 paramiko.transport INFO     Connected (version 2.0, client OpenSSH_8.2p1)
# 2023-01-24 21:28:36,463 paramiko.transport INFO     Authentication (publickey) successful!
# 2023-01-24 21:28:36,464 sagemaker-training-toolkit INFO     Can connect to host algo-3 at port 22
# 2023-01-24 21:28:36,464 sagemaker-training-toolkit INFO     Connection closed
# 2023-01-24 21:28:36,464 sagemaker-training-toolkit INFO     Worker algo-3 available for communication
# 2023-01-24 21:28:36,475 paramiko.transport INFO     Connected (version 2.0, client OpenSSH_8.2p1)
# 2023-01-24 21:28:36,551 paramiko.transport INFO     Authentication (publickey) successful!
# 2023-01-24 21:28:36,551 sagemaker-training-toolkit INFO     Can connect to host algo-1 at port 22
# 2023-01-24 21:28:36,551 sagemaker-training-toolkit INFO     Connection closed
# 2023-01-24 21:28:36,551 sagemaker-training-toolkit INFO     Worker algo-1 available for communication
# 2023-01-24 21:28:36,551 sagemaker-training-toolkit INFO     Network interface name: eth0
# 2023-01-24 21:28:36,551 sagemaker-training-toolkit INFO     Host: ['algo-4', 'algo-2', 'algo-3', 'algo-1']
# 2023-01-24 21:28:36,555 sagemaker-training-toolkit INFO     sagemaker_communication_backend: None
# 2023-01-24 21:28:36,555 sagemaker-training-toolkit WARNING  Missing library /opt/conda/lib/libsmddp.so for SMDDP collective
# 2023-01-24 21:28:36,555 sagemaker-training-toolkit WARNING  The system is not configured to run SMDDP collectives optimizedfor AWS infrastructure.Please use the latest SageMaker Deep Learning Container (DLC) to enable SMDDP Collectives support.
# Continuing model training with default NCCL communication backend.
# 2023-01-24 21:28:36,555 sagemaker-training-toolkit INFO     instance type: ml.p4d.24xlarge
# 2023-01-24 21:28:36,555 sagemaker-training-toolkit INFO     Env Hosts: ['algo-4', 'algo-2', 'algo-3', 'algo-1'] Hosts: ['algo-4:8', 'algo-2:8', 'algo-3:8', 'algo-1:8'] process_per_hosts: 8 num_processes: 32
# 2023-01-24 21:28:36,641 sagemaker-training-toolkit INFO     No Neurons detected (normal if no neurons installed)
# 2023-01-24 21:28:36,653 sagemaker-training-toolkit INFO     Invoking user script
# Training Env:
# {
#     "additional_framework_parameters": {
#         "sagemaker_distributed_dataparallel_custom_mpi_options": "",
#         "sagemaker_distributed_dataparallel_enabled": true,
#         "sagemaker_instance_type": "ml.p4d.24xlarge"
#     },
#     "channel_input_dirs": {},
#     "current_host": "algo-4",
#     "current_instance_group": "homogeneousCluster",
#     "current_instance_group_hosts": [
#         "algo-4",
#         "algo-2",
#         "algo-3",
#         "algo-1"
#     ],
#     "current_instance_type": "ml.p4d.24xlarge",
#     "distribution_hosts": [
#         "algo-4",
#         "algo-2",
#         "algo-3",
#         "algo-1"
#     ],
#     "distribution_instance_groups": [
#         "homogeneousCluster"
#     ],
#     "framework_module": "sagemaker_pytorch_container.training:main",
#     "hosts": [
#         "algo-1",
#         "algo-2",
#         "algo-3",
#         "algo-4"
#     ],
#     "hyperparameters": {
#         "batch-size": 512,
#         "dist-backend": "smddp",
#         "epochs": 50,
#         "log-every-n-steps": 100,
#         "log-path": "/opt/ml/checkpoints/logs/",
#         "lr": 0.0004,
#         "precision": "amp",
#         "train-data": "\"pipe:aws s3 cp s3://jbsnyder-sagemaker-us-west-2/data/laion/laion400m/data/{00000..02499}.tar -\"",
#         "train-num-samples": 16384000,
#         "val-data": "\"pipe:aws s3 cp s3://jbsnyder-sagemaker-us-west-2/data/laion/laion400m/data/{02500..02587}.tar -\"",
#         "val-num-samples": 10000,
#         "warmup": 2000,
#         "wd": 0.2,
#         "workers": 4
#     },
#     "input_config_dir": "/opt/ml/input/config",
#     "input_data_config": {},
#     "input_dir": "/opt/ml/input",
#     "instance_groups": [
#         "homogeneousCluster"
#     ],
#     "instance_groups_dict": {
#         "homogeneousCluster": {
#             "instance_group_name": "homogeneousCluster",
#             "instance_type": "ml.p4d.24xlarge",
#             "hosts": [
#                 "algo-4",
#                 "algo-2",
#                 "algo-3",
#                 "algo-1"
#             ]
#         }
#     },
#     "is_hetero": false,
#     "is_master": true,
#     "is_modelparallel_enabled": null,
#     "is_smddpmprun_installed": true,
#     "job_name": "openclip-scaling-24-01-2023-21-17-32",
#     "log_level": 20,
#     "master_hostname": "algo-4",
#     "model_dir": "/opt/ml/model",
#     "module_dir": "s3://jbsnyder-sagemaker-us-west-2/sagemaker-code/24-01-2023/openclip-scaling-24-01-2023-21-17-32/openclip-scaling-24-01-2023-21-17-32/source/sourcedir.tar.gz",
#     "module_name": "sm_train",
#     "network_interface_name": "eth0",
#     "num_cpus": 96,
#     "num_gpus": 8,
#     "num_neurons": 0,
#     "output_data_dir": "/opt/ml/output/data",
#     "output_dir": "/opt/ml/output",
#     "output_intermediate_dir": "/opt/ml/output/intermediate",
#     "resource_config": {
#         "current_host": "algo-4",
#         "current_instance_type": "ml.p4d.24xlarge",
#         "current_group_name": "homogeneousCluster",
#         "hosts": [
#             "algo-1",
#             "algo-2",
#             "algo-3",
#             "algo-4"
#         ],
#         "instance_groups": [
#             {
#                 "instance_group_name": "homogeneousCluster",
#                 "instance_type": "ml.p4d.24xlarge",
#                 "hosts": [
#                     "algo-4",
#                     "algo-2",
#                     "algo-3",
#                     "algo-1"
#                 ]
#             }
#         ],
#         "network_interface_name": "eth0"
#     },
#     "user_entry_point": "sm_train.py"
# }
# Environment variables:
# SM_HOSTS=["algo-1","algo-2","algo-3","algo-4"]
# SM_NETWORK_INTERFACE_NAME=eth0
# SM_HPS={"batch-size":512,"dist-backend":"smddp","epochs":50,"log-every-n-steps":100,"log-path":"/opt/ml/checkpoints/logs/","lr":0.0004,"precision":"amp","train-data":"\"pipe:aws s3 cp s3://jbsnyder-sagemaker-us-west-2/data/laion/laion400m/data/{00000..02499}.tar -\"","train-num-samples":16384000,"val-data":"\"pipe:aws s3 cp s3://jbsnyder-sagemaker-us-west-2/data/laion/laion400m/data/{02500..02587}.tar -\"","val-num-samples":10000,"warmup":2000,"wd":0.2,"workers":4}
# SM_USER_ENTRY_POINT=sm_train.py
# SM_FRAMEWORK_PARAMS={"sagemaker_distributed_dataparallel_custom_mpi_options":"","sagemaker_distributed_dataparallel_enabled":true,"sagemaker_instance_type":"ml.p4d.24xlarge"}
# SM_RESOURCE_CONFIG={"current_group_name":"homogeneousCluster","current_host":"algo-4","current_instance_type":"ml.p4d.24xlarge","hosts":["algo-1","algo-2","algo-3","algo-4"],"instance_groups":[{"hosts":["algo-4","algo-2","algo-3","algo-1"],"instance_group_name":"homogeneousCluster","instance_type":"ml.p4d.24xlarge"}],"network_interface_name":"eth0"}
# SM_INPUT_DATA_CONFIG={}
# SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# SM_CHANNELS=[]
# SM_CURRENT_HOST=algo-4
# SM_CURRENT_INSTANCE_TYPE=ml.p4d.24xlarge
# SM_CURRENT_INSTANCE_GROUP=homogeneousCluster
# SM_CURRENT_INSTANCE_GROUP_HOSTS=["algo-4","algo-2","algo-3","algo-1"]
# SM_INSTANCE_GROUPS=["homogeneousCluster"]
# SM_INSTANCE_GROUPS_DICT={"homogeneousCluster":{"hosts":["algo-4","algo-2","algo-3","algo-1"],"instance_group_name":"homogeneousCluster","instance_type":"ml.p4d.24xlarge"}}
# SM_DISTRIBUTION_INSTANCE_GROUPS=["homogeneousCluster"]
# SM_IS_HETERO=false
# SM_MODULE_NAME=sm_train
# SM_LOG_LEVEL=20
# SM_FRAMEWORK_MODULE=sagemaker_pytorch_container.training:main
# SM_INPUT_DIR=/opt/ml/input
# SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# SM_OUTPUT_DIR=/opt/ml/output
# SM_NUM_CPUS=96
# SM_NUM_GPUS=8
# SM_NUM_NEURONS=0
# SM_MODEL_DIR=/opt/ml/model
# SM_MODULE_DIR=s3://jbsnyder-sagemaker-us-west-2/sagemaker-code/24-01-2023/openclip-scaling-24-01-2023-21-17-32/openclip-scaling-24-01-2023-21-17-32/source/sourcedir.tar.gz
# SM_TRAINING_ENV={"additional_framework_parameters":{"sagemaker_distributed_dataparallel_custom_mpi_options":"","sagemaker_distributed_dataparallel_enabled":true,"sagemaker_instance_type":"ml.p4d.24xlarge"},"channel_input_dirs":{},"current_host":"algo-4","current_instance_group":"homogeneousCluster","current_instance_group_hosts":["algo-4","algo-2","algo-3","algo-1"],"current_instance_type":"ml.p4d.24xlarge","distribution_hosts":["algo-4","algo-2","algo-3","algo-1"],"distribution_instance_groups":["homogeneousCluster"],"framework_module":"sagemaker_pytorch_container.training:main","hosts":["algo-1","algo-2","algo-3","algo-4"],"hyperparameters":{"batch-size":512,"dist-backend":"smddp","epochs":50,"log-every-n-steps":100,"log-path":"/opt/ml/checkpoints/logs/","lr":0.0004,"precision":"amp","train-data":"\"pipe:aws s3 cp s3://jbsnyder-sagemaker-us-west-2/data/laion/laion400m/data/{00000..02499}.tar -\"","train-num-samples":16384000,"val-data":"\"pipe:aws s3 cp s3://jbsnyder-sagemaker-us-west-2/data/laion/laion400m/data/{02500..02587}.tar -\"","val-num-samples":10000,"warmup":2000,"wd":0.2,"workers":4},"input_config_dir":"/opt/ml/input/config","input_data_config":{},"input_dir":"/opt/ml/input","instance_groups":["homogeneousCluster"],"instance_groups_dict":{"homogeneousCluster":{"hosts":["algo-4","algo-2","algo-3","algo-1"],"instance_group_name":"homogeneousCluster","instance_type":"ml.p4d.24xlarge"}},"is_hetero":false,"is_master":true,"is_modelparallel_enabled":null,"is_smddpmprun_installed":true,"job_name":"openclip-scaling-24-01-2023-21-17-32","log_level":20,"master_hostname":"algo-4","model_dir":"/opt/ml/model","module_dir":"s3://jbsnyder-sagemaker-us-west-2/sagemaker-code/24-01-2023/openclip-scaling-24-01-2023-21-17-32/openclip-scaling-24-01-2023-21-17-32/source/sourcedir.tar.gz","module_name":"sm_train","network_interface_name":"eth0","num_cpus":96,"num_gpus":8,"num_neurons":0,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_group_name":"homogeneousCluster","current_host":"algo-4","current_instance_type":"ml.p4d.24xlarge","hosts":["algo-1","algo-2","algo-3","algo-4"],"instance_groups":[{"hosts":["algo-4","algo-2","algo-3","algo-1"],"instance_group_name":"homogeneousCluster","instance_type":"ml.p4d.24xlarge"}],"network_interface_name":"eth0"},"user_entry_point":"sm_train.py"}
# SM_USER_ARGS=["--batch-size","512","--dist-backend","smddp","--epochs","50","--log-every-n-steps","100","--log-path","/opt/ml/checkpoints/logs/","--lr","0.0004","--precision","amp","--train-data","\"pipe:aws s3 cp s3://jbsnyder-sagemaker-us-west-2/data/laion/laion400m/data/{00000..02499}.tar -\"","--train-num-samples","16384000","--val-data","\"pipe:aws s3 cp s3://jbsnyder-sagemaker-us-west-2/data/laion/laion400m/data/{02500..02587}.tar -\"","--val-num-samples","10000","--warmup","2000","--wd","0.2","--workers","4"]
# SM_OUTPUT_INTERMEDIATE_DIR=/opt/ml/output/intermediate
# SM_HP_BATCH-SIZE=512
# SM_HP_DIST-BACKEND=smddp
# SM_HP_EPOCHS=50
# SM_HP_LOG-EVERY-N-STEPS=100
# SM_HP_LOG-PATH=/opt/ml/checkpoints/logs/
# SM_HP_LR=0.0004
# SM_HP_PRECISION=amp
# SM_HP_TRAIN-DATA="pipe:aws s3 cp s3://jbsnyder-sagemaker-us-west-2/data/laion/laion400m/data/{00000..02499}.tar -"
# SM_HP_TRAIN-NUM-SAMPLES=16384000
# SM_HP_VAL-DATA="pipe:aws s3 cp s3://jbsnyder-sagemaker-us-west-2/data/laion/laion400m/data/{02500..02587}.tar -"
# SM_HP_VAL-NUM-SAMPLES=10000
# SM_HP_WARMUP=2000
# SM_HP_WD=0.2
# SM_HP_WORKERS=4
# PYTHONPATH=/opt/ml/code:/opt/conda/bin:/opt/conda/lib/python38.zip:/opt/conda/lib/python3.8:/opt/conda/lib/python3.8/lib-dynload:/opt/conda/lib/python3.8/site-packages:/opt/conda/lib/python3.8/site-packages/pyinstrument-3.4.2-py3.8.egg:/opt/conda/lib/python3.8/site-packages/pyinstrument_cext-0.2.4-py3.8-linux-x86_64.egg:/opt/conda/lib/python3.8/site-packages/flash_attn-0.1-py3.8-linux-x86_64.egg:/opt/conda/lib/python3.8/site-packages/einops-0.6.0-py3.8.egg
# Invoking script with the following command:
# mpirun --host algo-4:8,algo-2:8,algo-3:8,algo-1:8 -np 32 --allow-run-as-root --tag-output --oversubscribe -mca btl_tcp_if_include eth0 -mca oob_tcp_if_include eth0 -mca plm_rsh_no_tree_spawn 1 -mca pml ob1 -mca btl ^openib -mca orte_abort_on_non_zero_status 1 -mca btl_vader_single_copy_mechanism none -mca plm_rsh_num_concurrent 4 -x NCCL_SOCKET_IFNAME=eth0 -x NCCL_DEBUG=INFO -x LD_LIBRARY_PATH -x PATH -x SMDATAPARALLEL_USE_HOMOGENEOUS=1 -x FI_PROVIDER=efa -x RDMAV_FORK_SAFE=1 -x LD_PRELOAD=/opt/conda/lib/python3.8/site-packages/gethostname.cpython-38-x86_64-linux-gnu.so -x NCCL_PROTO=simple -x FI_EFA_USE_DEVICE_RDMA=1 -x SMDATAPARALLEL_SERVER_ADDR=algo-4 -x SMDATAPARALLEL_SERVER_PORT=7592 -x SAGEMAKER_INSTANCE_TYPE=ml.p4d.24xlarge -x USE_SMDDP_COLLECTIVES=0 smddprun /opt/conda/bin/python3.8 -m mpi4py sm_train.py --batch-size 512 --dist-backend smddp --epochs 50 --log-every-n-steps 100 --log-path /opt/ml/checkpoints/logs/ --lr 0.0004 --precision amp --train-data "pipe:aws s3 cp s3://jbsnyder-sagemaker-us-west-2/data/laion/laion400m/data/{00000..02499}.tar -" --train-num-samples 16384000 --val-data "pipe:aws s3 cp s3://jbsnyder-sagemaker-us-west-2/data/laion/laion400m/data/{02500..02587}.tar -" --val-num-samples 10000 --warmup 2000 --wd 0.2 --workers 4
# [2023-01-24 21:28:41.388: W smdistributed/modelparallel/torch/nn/predefined_hooks.py:78] Found unsupported HuggingFace version 4.25.1 for automated tensor parallelism. HuggingFace modules will not be automatically distributed. You can use smp.tp_register_with_module API to register desired modules for tensor parallelism, or directly instantiate an smp.nn.DistributedModule. Supported HuggingFace transformers versions for automated tensor parallelism: ['4.17.0', '4.20.1', '4.21.0']
# 2023-01-24 21:28:42,374 sagemaker-training-toolkit INFO     Process[es]: [psutil.Process(pid=59, name='orted', status='sleeping', started='21:28:41')]
# 2023-01-24 21:28:42,374 sagemaker-training-toolkit INFO     Orted process found [psutil.Process(pid=59, name='orted', status='sleeping', started='21:28:41')]
# 2023-01-24 21:28:42,374 sagemaker-training-toolkit INFO     Waiting for orted process [psutil.Process(pid=59, name='orted', status='sleeping', started='21:28:41')]
# 2023-01-24 21:28:42,374 sagemaker-training-toolkit INFO     Process[es]: [psutil.Process(pid=59, name='orted', status='sleeping', started='21:28:41')]
# 2023-01-24 21:28:42,374 sagemaker-training-toolkit INFO     Orted process found [psutil.Process(pid=59, name='orted', status='sleeping', started='21:28:41')]
# 2023-01-24 21:28:42,375 sagemaker-training-toolkit INFO     Waiting for orted process [psutil.Process(pid=59, name='orted', status='sleeping', started='21:28:41')]
# Warning: Permanently added 'algo-2,10.0.118.186' (ECDSA) to the list of known hosts.
# Warning: Permanently added 'algo-3,10.0.111.76' (ECDSA) to the list of known hosts.
# Warning: Permanently added 'algo-1,10.0.97.42' (ECDSA) to the list of known hosts.
# [1,mpirank:0,algo-1]<stderr>:curl: /opt/conda/lib/libcurl.so.4: no version information available (required by curl)
# [1,mpirank:24,algo-4]<stderr>:curl: /opt/conda/lib/libcurl.so.4: no version information available (required by curl)
# [1,mpirank:16,algo-3]<stderr>:curl: /opt/conda/lib/libcurl.so.4: no version information available (required by curl)
# [1,mpirank:8,algo-2]<stderr>:curl: /opt/conda/lib/libcurl.so.4: no version information available (required by curl)
# [1,mpirank:0,algo-1]<stderr>:curl: /opt/conda/lib/libcurl.so.4: no version information available (required by curl)
# [1,mpirank:8,algo-2]<stderr>:curl: /opt/conda/lib/libcurl.so.4: no version information available (required by curl)
# [1,mpirank:24,algo-4]<stderr>:curl: /opt/conda/lib/libcurl.so.4: no version information available (required by curl)
# [1,mpirank:16,algo-3]<stderr>:curl: /opt/conda/lib/libcurl.so.4: no version information available (required by curl)
# [1,mpirank:0,algo-1]<stderr>:curl: /opt/conda/lib/libcurl.so.4: no version information available (required by curl)
# [1,mpirank:24,algo-4]<stderr>:curl: /opt/conda/lib/libcurl.so.4: no version information available (required by curl)
# [1,mpirank:8,algo-2]<stderr>:curl: /opt/conda/lib/libcurl.so.4: no version information available (required by curl)
# [1,mpirank:16,algo-3]<stderr>:curl: /opt/conda/lib/libcurl.so.4: no version information available (required by curl)
# 2023-01-24 21:28:42,523 sagemaker-training-toolkit INFO     Process[es]: [psutil.Process(pid=59, name='orted', status='sleeping', started='21:28:41')]
# 2023-01-24 21:28:42,523 sagemaker-training-toolkit INFO     Orted process found [psutil.Process(pid=59, name='orted', status='sleeping', started='21:28:41')]
# 2023-01-24 21:28:42,523 sagemaker-training-toolkit INFO     Waiting for orted process [psutil.Process(pid=59, name='orted', status='sleeping', started='21:28:41')]
# [1,mpirank:7,algo-1]<stdout>:[2023-01-24 21:28:46.583: W smdistributed/modelparallel/torch/nn/predefined_hooks.py:78] Found unsupported HuggingFace version 4.25.1 for automated tensor parallelism. HuggingFace modules will not be automatically distributed. You can use smp.tp_register_with_module API to register desired modules for tensor parallelism, or directly instantiate an smp.nn.DistributedModule. Supported HuggingFace transformers versions for automated tensor parallelism: ['4.17.0', '4.20.1', '4.21.0']
# [1,mpirank:5,algo-1]<stdout>:[2023-01-24 21:28:46.584: W smdistributed/modelparallel/torch/nn/predefined_hooks.py:78] Found unsupported HuggingFace version 4.25.1 for automated tensor parallelism. HuggingFace modules will not be automatically distributed. You can use smp.tp_register_with_module API to register desired modules for tensor parallelism, or directly instantiate an smp.nn.DistributedModule. Supported HuggingFace transformers versions for automated tensor parallelism: ['4.17.0', '4.20.1', '4.21.0']
# [1,mpirank:6,algo-1]<stdout>:[2023-01-24 21:28:46.585: W smdistributed/modelparallel/torch/nn/predefined_hooks.py:78] Found unsupported HuggingFace version 4.25.1 for automated tensor parallelism. HuggingFace modules will not be automatically distributed. You can use smp.tp_register_with_module API to register desired modules for tensor parallelism, or directly instantiate an smp.nn.DistributedModule. Supported HuggingFace transformers versions for automated tensor parallelism: ['4.17.0', '4.20.1', '4.21.0']
# [1,mpirank:4,algo-1]<stdout>:[2023-01-24 21:28:46.585: W smdistributed/modelparallel/torch/nn/predefined_hooks.py:78] Found unsupported HuggingFace version 4.25.1 for automated tensor parallelism. HuggingFace modules will not be automatically distributed. You can use smp.tp_register_with_module API to register desired modules for tensor parallelism, or directly instantiate an smp.nn.DistributedModule. Supported HuggingFace transformers versions for automated tensor parallelism: ['4.17.0', '4.20.1', '4.21.0']
# [1,mpirank:1,algo-1]<stdout>:[2023-01-24 21:28:46.589: W smdistributed/modelparallel/torch/nn/predefined_hooks.py:78] Found unsupported HuggingFace version 4.25.1 for automated tensor parallelism. HuggingFace modules will not be automatically distributed. You can use smp.tp_register_with_module API to register desired modules for tensor parallelism, or directly instantiate an smp.nn.DistributedModule. Supported HuggingFace transformers versions for automated tensor parallelism: ['4.17.0', '4.20.1', '4.21.0']
# [1,mpirank:2,algo-1]<stdout>:[2023-01-24 21:28:46.589: W smdistributed/modelparallel/torch/nn/predefined_hooks.py:78] Found unsupported HuggingFace version 4.25.1 for automated tensor parallelism. HuggingFace modules will not be automatically distributed. You can use smp.tp_register_with_module API to register desired modules for tensor parallelism, or directly instantiate an smp.nn.DistributedModule. Supported HuggingFace transformers versions for automated tensor parallelism: ['4.17.0', '4.20.1', '4.21.0']
# [1,mpirank:3,algo-1]<stdout>:[2023-01-24 21:28:46.589: W smdistributed/modelparallel/torch/nn/predefined_hooks.py:78] Found unsupported HuggingFace version 4.25.1 for automated tensor parallelism. HuggingFace modules will not be automatically distributed. You can use smp.tp_register_with_module API to register desired modules for tensor parallelism, or directly instantiate an smp.nn.DistributedModule. Supported HuggingFace transformers versions for automated tensor parallelism: ['4.17.0', '4.20.1', '4.21.0']
# [1,mpirank:0,algo-1]<stdout>:[2023-01-24 21:28:46.589: W smdistributed/modelparallel/torch/nn/predefined_hooks.py:78] Found unsupported HuggingFace version 4.25.1 for automated tensor parallelism. HuggingFace modules will not be automatically distributed. You can use smp.tp_register_with_module API to register desired modules for tensor parallelism, or directly instantiate an smp.nn.DistributedModule. Supported HuggingFace transformers versions for automated tensor parallelism: ['4.17.0', '4.20.1', '4.21.0']
# [1,mpirank:3,algo-1]<stdout>:[2023-01-24 21:28:46.834 algo-4:337 INFO utils.py:27] RULE_JOB_STOP_SIGNAL_FILENAME: None
# [1,mpirank:4,algo-1]<stdout>:[2023-01-24 21:28:46.834 algo-4:351 INFO utils.py:27] RULE_JOB_STOP_SIGNAL_FILENAME: None
# [1,mpirank:1,algo-1]<stdout>:[2023-01-24 21:28:46.834 algo-4:302 INFO utils.py:27] RULE_JOB_STOP_SIGNAL_FILENAME: None
# [1,mpirank:2,algo-1]<stdout>:[2023-01-24 21:28:46.834 algo-4:341 INFO utils.py:27] RULE_JOB_STOP_SIGNAL_FILENAME: None
# [1,mpirank:6,algo-1]<stdout>:[2023-01-24 21:28:46.834 algo-4:303 INFO utils.py:27] RULE_JOB_STOP_SIGNAL_FILENAME: None
# [1,mpirank:7,algo-1]<stdout>:[2023-01-24 21:28:46.834 algo-4:301 INFO utils.py:27] RULE_JOB_STOP_SIGNAL_FILENAME: None
# [1,mpirank:5,algo-1]<stdout>:[2023-01-24 21:28:46.834 algo-4:340 INFO utils.py:27] RULE_JOB_STOP_SIGNAL_FILENAME: None
# [1,mpirank:0,algo-1]<stdout>:[2023-01-24 21:28:46.834 algo-4:406 INFO utils.py:27] RULE_JOB_STOP_SIGNAL_FILENAME: None
# [1,mpirank:3,algo-1]<stdout>:DDP Mode
# [1,mpirank:3,algo-1]<stdout>:[2023-01-24 21:28:48.595 algo-4:337 INFO profiler_config_parser.py:111] User has disabled profiler.
# [1,mpirank:3,algo-1]<stdout>:
# [1,mpirank:3,algo-1]<stdout>:
# [1,mpirank:3,algo-1]<stdout>:Rank 3 local rank 3 of 32
# [1,mpirank:3,algo-1]<stdout>:
# [1,mpirank:3,algo-1]<stdout>:
# [1,mpirank:4,algo-1]<stdout>:DDP Mode
# [1,mpirank:4,algo-1]<stdout>:[2023-01-24 21:28:48.600 algo-4:351 INFO profiler_config_parser.py:111] User has disabled profiler.
# [1,mpirank:5,algo-1]<stdout>:DDP Mode
# [1,mpirank:4,algo-1]<stdout>:
# [1,mpirank:4,algo-1]<stdout>:
# [1,mpirank:4,algo-1]<stdout>:Rank 4 local rank 4 of 32
# [1,mpirank:4,algo-1]<stdout>:
# [1,mpirank:4,algo-1]<stdout>:
# [1,mpirank:5,algo-1]<stdout>:[2023-01-24 21:28:48.602 algo-4:340 INFO profiler_config_parser.py:111] User has disabled profiler.
# [1,mpirank:5,algo-1]<stdout>:
# [1,mpirank:5,algo-1]<stdout>:
# [1,mpirank:5,algo-1]<stdout>:Rank 5 local rank 5 of 32
# [1,mpirank:5,algo-1]<stdout>:
# [1,mpirank:5,algo-1]<stdout>:
# [1,mpirank:6,algo-1]<stdout>:DDP Mode
# [1,mpirank:6,algo-1]<stdout>:[2023-01-24 21:28:48.619 algo-4:303 INFO profiler_config_parser.py:111] User has disabled profiler.
# [1,mpirank:6,algo-1]<stdout>:
# [1,mpirank:6,algo-1]<stdout>:
# [1,mpirank:6,algo-1]<stdout>:Rank 6 local rank 6 of 32
# [1,mpirank:6,algo-1]<stdout>:
# [1,mpirank:6,algo-1]<stdout>:
# [1,mpirank:1,algo-1]<stdout>:DDP Mode
# [1,mpirank:1,algo-1]<stdout>:[2023-01-24 21:28:48.652 algo-4:302 INFO profiler_config_parser.py:111] User has disabled profiler.
# [1,mpirank:0,algo-1]<stdout>:DDP Mode
# [1,mpirank:0,algo-1]<stdout>:[2023-01-24 21:28:48.653 algo-4:406 INFO profiler_config_parser.py:111] User has disabled profiler.
# [1,mpirank:1,algo-1]<stdout>:
# [1,mpirank:1,algo-1]<stdout>:
# [1,mpirank:1,algo-1]<stdout>:Rank 1 local rank 1 of 32
# [1,mpirank:1,algo-1]<stdout>:
# [1,mpirank:1,algo-1]<stdout>:
# [1,mpirank:0,algo-1]<stdout>:
# [1,mpirank:0,algo-1]<stdout>:
# [1,mpirank:0,algo-1]<stdout>:Rank 0 local rank 0 of 32
# [1,mpirank:0,algo-1]<stdout>:
# [1,mpirank:0,algo-1]<stdout>:
# [1,mpirank:0,algo-1]<stdout>:Namespace(accum_freq=1, batch_size=512, beta1=0.9, beta2=0.98, dataset_type='webdataset', ddp_static_graph=False, debug=False, dist_backend='smddp', dist_url='env://', epochs=50, eps=1e-06, force_custom_text=False, force_patch_dropout=None, force_quick_gelu=False, gather_with_grad=False, grad_clip_norm=None, horovod=False, image_mean=None, image_std=None, imagenet_v2=None, imagenet_val=None, local_loss=False, log_every_n_steps=100, log_level=20, log_path='/opt/ml/checkpoints/logs/', lr=0.0004, model='ViT-B-32', name='proto_1', no_set_device_rank=False, precision='amp', pretrained=None, pretrained_image=False, seed=0, skip_scheduler=False, torchscript=False, train_data='pipe:aws s3 cp s3://jbsnyder-sagemaker-us-west-2/data/laion/laion400m/data/{00000..02499}.tar -', train_num_samples=16384000, use_bn_sync=True, val_data='pipe:aws s3 cp s3://jbsnyder-sagemaker-us-west-2/data/laion/laion400m/data/{02500..02587}.tar -', val_frequency=1, val_num_samples=10000, wandb=False, warmup=2000, wd=0.2, workers=4)
# [1,mpirank:7,algo-1]<stdout>:DDP Mode
# [1,mpirank:7,algo-1]<stdout>:[2023-01-24 21:28:48.655 algo-4:301 INFO profiler_config_parser.py:111] User has disabled profiler.
# [1,mpirank:2,algo-1]<stdout>:DDP Mode
# [1,mpirank:2,algo-1]<stdout>:[2023-01-24 21:28:48.656 algo-4:341 INFO profiler_config_parser.py:111] User has disabled profiler.
# [1,mpirank:7,algo-1]<stdout>:
# [1,mpirank:7,algo-1]<stdout>:
# [1,mpirank:7,algo-1]<stdout>:Rank 7 local rank 7 of 32
# [1,mpirank:7,algo-1]<stdout>:
# [1,mpirank:7,algo-1]<stdout>:
# [1,mpirank:2,algo-1]<stdout>:
# [1,mpirank:2,algo-1]<stdout>:
# [1,mpirank:2,algo-1]<stdout>:Rank 2 local rank 2 of 32
# [1,mpirank:2,algo-1]<stdout>:
# [1,mpirank:2,algo-1]<stdout>:
# [1,mpirank:8,algo-2]<stdout>:[2023-01-24 21:28:50.148: W smdistributed/modelparallel/torch/nn/predefined_hooks.py:78] Found unsupported HuggingFace version 4.25.1 for automated tensor parallelism. HuggingFace modules will not be automatically distributed. You can use smp.tp_register_with_module API to register desired modules for tensor parallelism, or directly instantiate an smp.nn.DistributedModule. Supported HuggingFace transformers versions for automated tensor parallelism: ['4.17.0', '4.20.1', '4.21.0']
# [1,mpirank:9,algo-2]<stdout>:[2023-01-24 21:28:50.148: W smdistributed/modelparallel/torch/nn/predefined_hooks.py:78] Found unsupported HuggingFace version 4.25.1 for automated tensor parallelism. HuggingFace modules will not be automatically distributed. You can use smp.tp_register_with_module API to register desired modules for tensor parallelism, or directly instantiate an smp.nn.DistributedModule. Supported HuggingFace transformers versions for automated tensor parallelism: ['4.17.0', '4.20.1', '4.21.0']
# [1,mpirank:10,algo-2]<stdout>:[2023-01-24 21:28:50.148: W smdistributed/modelparallel/torch/nn/predefined_hooks.py:78] Found unsupported HuggingFace version 4.25.1 for automated tensor parallelism. HuggingFace modules will not be automatically distributed. You can use smp.tp_register_with_module API to register desired modules for tensor parallelism, or directly instantiate an smp.nn.DistributedModule. Supported HuggingFace transformers versions for automated tensor parallelism: ['4.17.0', '4.20.1', '4.21.0']
# [1,mpirank:12,algo-2]<stdout>:[2023-01-24 21:28:50.148: W smdistributed/modelparallel/torch/nn/predefined_hooks.py:78] Found unsupported HuggingFace version 4.25.1 for automated tensor parallelism. HuggingFace modules will not be automatically distributed. You can use smp.tp_register_with_module API to register desired modules for tensor parallelism, or directly instantiate an smp.nn.DistributedModule. Supported HuggingFace transformers versions for automated tensor parallelism: ['4.17.0', '4.20.1', '4.21.0']
# [1,mpirank:13,algo-2]<stdout>:[2023-01-24 21:28:50.148: W smdistributed/modelparallel/torch/nn/predefined_hooks.py:78] Found unsupported HuggingFace version 4.25.1 for automated tensor parallelism. HuggingFace modules will not be automatically distributed. You can use smp.tp_register_with_module API to register desired modules for tensor parallelism, or directly instantiate an smp.nn.DistributedModule. Supported HuggingFace transformers versions for automated tensor parallelism: ['4.17.0', '4.20.1', '4.21.0']
# [1,mpirank:15,algo-2]<stdout>:[2023-01-24 21:28:50.148: W smdistributed/modelparallel/torch/nn/predefined_hooks.py:78] Found unsupported HuggingFace version 4.25.1 for automated tensor parallelism. HuggingFace modules will not be automatically distributed. You can use smp.tp_register_with_module API to register desired modules for tensor parallelism, or directly instantiate an smp.nn.DistributedModule. Supported HuggingFace transformers versions for automated tensor parallelism: ['4.17.0', '4.20.1', '4.21.0']
# [1,mpirank:11,algo-2]<stdout>:[2023-01-24 21:28:50.148: W smdistributed/modelparallel/torch/nn/predefined_hooks.py:78] Found unsupported HuggingFace version 4.25.1 for automated tensor parallelism. HuggingFace modules will not be automatically distributed. You can use smp.tp_register_with_module API to register desired modules for tensor parallelism, or directly instantiate an smp.nn.DistributedModule. Supported HuggingFace transformers versions for automated tensor parallelism: ['4.17.0', '4.20.1', '4.21.0']
# [1,mpirank:14,algo-2]<stdout>:[2023-01-24 21:28:50.149: W smdistributed/modelparallel/torch/nn/predefined_hooks.py:78] Found unsupported HuggingFace version 4.25.1 for automated tensor parallelism. HuggingFace modules will not be automatically distributed. You can use smp.tp_register_with_module API to register desired modules for tensor parallelism, or directly instantiate an smp.nn.DistributedModule. Supported HuggingFace transformers versions for automated tensor parallelism: ['4.17.0', '4.20.1', '4.21.0']
# [1,mpirank:8,algo-2]<stdout>:[2023-01-24 21:28:50.546 algo-2:280 INFO utils.py:27] RULE_JOB_STOP_SIGNAL_FILENAME: None
# [1,mpirank:9,algo-2]<stdout>:[2023-01-24 21:28:50.546 algo-2:179 INFO utils.py:27] RULE_JOB_STOP_SIGNAL_FILENAME: None
# [1,mpirank:15,algo-2]<stdout>:[2023-01-24 21:28:50.546 algo-2:178 INFO utils.py:27] RULE_JOB_STOP_SIGNAL_FILENAME: None
# [1,mpirank:10,algo-2]<stdout>:[2023-01-24 21:28:50.546 algo-2:213 INFO utils.py:27] RULE_JOB_STOP_SIGNAL_FILENAME: None
# [1,mpirank:12,algo-2]<stdout>:[2023-01-24 21:28:50.546 algo-2:175 INFO utils.py:27] RULE_JOB_STOP_SIGNAL_FILENAME: None
# [1,mpirank:11,algo-2]<stdout>:[2023-01-24 21:28:50.546 algo-2:214 INFO utils.py:27] RULE_JOB_STOP_SIGNAL_FILENAME: None
# [1,mpirank:13,algo-2]<stdout>:[2023-01-24 21:28:50.546 algo-2:176 INFO utils.py:27] RULE_JOB_STOP_SIGNAL_FILENAME: None
# [1,mpirank:14,algo-2]<stdout>:[2023-01-24 21:28:50.547 algo-2:177 INFO utils.py:27] RULE_JOB_STOP_SIGNAL_FILENAME: None
# [1,mpirank:16,algo-3]<stdout>:[2023-01-24 21:28:50.564: W smdistributed/modelparallel/torch/nn/predefined_hooks.py:78] Found unsupported HuggingFace version 4.25.1 for automated tensor parallelism. HuggingFace modules will not be automatically distributed. You can use smp.tp_register_with_module API to register desired modules for tensor parallelism, or directly instantiate an smp.nn.DistributedModule. Supported HuggingFace transformers versions for automated tensor parallelism: ['4.17.0', '4.20.1', '4.21.0']
# [1,mpirank:17,algo-3]<stdout>:[2023-01-24 21:28:50.564: W smdistributed/modelparallel/torch/nn/predefined_hooks.py:78] Found unsupported HuggingFace version 4.25.1 for automated tensor parallelism. HuggingFace modules will not be automatically distributed. You can use smp.tp_register_with_module API to register desired modules for tensor parallelism, or directly instantiate an smp.nn.DistributedModule. Supported HuggingFace transformers versions for automated tensor parallelism: ['4.17.0', '4.20.1', '4.21.0']
# [1,mpirank:18,algo-3]<stdout>:[2023-01-24 21:28:50.564: W smdistributed/modelparallel/torch/nn/predefined_hooks.py:78] Found unsupported HuggingFace version 4.25.1 for automated tensor parallelism. HuggingFace modules will not be automatically distributed. You can use smp.tp_register_with_module API to register desired modules for tensor parallelism, or directly instantiate an smp.nn.DistributedModule. Supported HuggingFace transformers versions for automated tensor parallelism: ['4.17.0', '4.20.1', '4.21.0']
# [1,mpirank:19,algo-3]<stdout>:[2023-01-24 21:28:50.564: W smdistributed/modelparallel/torch/nn/predefined_hooks.py:78] Found unsupported HuggingFace version 4.25.1 for automated tensor parallelism. HuggingFace modules will not be automatically distributed. You can use smp.tp_register_with_module API to register desired modules for tensor parallelism, or directly instantiate an smp.nn.DistributedModule. Supported HuggingFace transformers versions for automated tensor parallelism: ['4.17.0', '4.20.1', '4.21.0']
# [1,mpirank:20,algo-3]<stdout>:[2023-01-24 21:28:50.564: W smdistributed/modelparallel/torch/nn/predefined_hooks.py:78] Found unsupported HuggingFace version 4.25.1 for automated tensor parallelism. HuggingFace modules will not be automatically distributed. You can use smp.tp_register_with_module API to register desired modules for tensor parallelism, or directly instantiate an smp.nn.DistributedModule. Supported HuggingFace transformers versions for automated tensor parallelism: ['4.17.0', '4.20.1', '4.21.0']
# [1,mpirank:21,algo-3]<stdout>:[2023-01-24 21:28:50.564: W smdistributed/modelparallel/torch/nn/predefined_hooks.py:78] Found unsupported HuggingFace version 4.25.1 for automated tensor parallelism. HuggingFace modules will not be automatically distributed. You can use smp.tp_register_with_module API to register desired modules for tensor parallelism, or directly instantiate an smp.nn.DistributedModule. Supported HuggingFace transformers versions for automated tensor parallelism: ['4.17.0', '4.20.1', '4.21.0']
# [1,mpirank:22,algo-3]<stdout>:[2023-01-24 21:28:50.564: W smdistributed/modelparallel/torch/nn/predefined_hooks.py:78] Found unsupported HuggingFace version 4.25.1 for automated tensor parallelism. HuggingFace modules will not be automatically distributed. You can use smp.tp_register_with_module API to register desired modules for tensor parallelism, or directly instantiate an smp.nn.DistributedModule. Supported HuggingFace transformers versions for automated tensor parallelism: ['4.17.0', '4.20.1', '4.21.0']
# [1,mpirank:23,algo-3]<stdout>:[2023-01-24 21:28:50.564: W smdistributed/modelparallel/torch/nn/predefined_hooks.py:78] Found unsupported HuggingFace version 4.25.1 for automated tensor parallelism. HuggingFace modules will not be automatically distributed. You can use smp.tp_register_with_module API to register desired modules for tensor parallelism, or directly instantiate an smp.nn.DistributedModule. Supported HuggingFace transformers versions for automated tensor parallelism: ['4.17.0', '4.20.1', '4.21.0']
# [1,mpirank:16,algo-3]<stdout>:[2023-01-24 21:28:50.968 algo-3:280 INFO utils.py:27] RULE_JOB_STOP_SIGNAL_FILENAME: None
# [1,mpirank:17,algo-3]<stdout>:[2023-01-24 21:28:50.968 algo-3:210 INFO utils.py:27] RULE_JOB_STOP_SIGNAL_FILENAME: None
# [1,mpirank:18,algo-3]<stdout>:[2023-01-24 21:28:50.968 algo-3:175 INFO utils.py:27] RULE_JOB_STOP_SIGNAL_FILENAME: None
# [1,mpirank:19,algo-3]<stdout>:[2023-01-24 21:28:50.968 algo-3:176 INFO utils.py:27] RULE_JOB_STOP_SIGNAL_FILENAME: None
# [1,mpirank:20,algo-3]<stdout>:[2023-01-24 21:28:50.968 algo-3:204 INFO utils.py:27] RULE_JOB_STOP_SIGNAL_FILENAME: None
# [1,mpirank:21,algo-3]<stdout>:[2023-01-24 21:28:50.968 algo-3:211 INFO utils.py:27] RULE_JOB_STOP_SIGNAL_FILENAME: None
# [1,mpirank:23,algo-3]<stdout>:[2023-01-24 21:28:50.968 algo-3:177 INFO utils.py:27] RULE_JOB_STOP_SIGNAL_FILENAME: None
# [1,mpirank:22,algo-3]<stdout>:[2023-01-24 21:28:50.970 algo-3:200 INFO utils.py:27] RULE_JOB_STOP_SIGNAL_FILENAME: None
# [1,mpirank:24,algo-4]<stdout>:[2023-01-24 21:28:51.056: W smdistributed/modelparallel/torch/nn/predefined_hooks.py:78] Found unsupported HuggingFace version 4.25.1 for automated tensor parallelism. HuggingFace modules will not be automatically distributed. You can use smp.tp_register_with_module API to register desired modules for tensor parallelism, or directly instantiate an smp.nn.DistributedModule. Supported HuggingFace transformers versions for automated tensor parallelism: ['4.17.0', '4.20.1', '4.21.0']
# [1,mpirank:25,algo-4]<stdout>:[2023-01-24 21:28:51.056: W smdistributed/modelparallel/torch/nn/predefined_hooks.py:78] Found unsupported HuggingFace version 4.25.1 for automated tensor parallelism. HuggingFace modules will not be automatically distributed. You can use smp.tp_register_with_module API to register desired modules for tensor parallelism, or directly instantiate an smp.nn.DistributedModule. Supported HuggingFace transformers versions for automated tensor parallelism: ['4.17.0', '4.20.1', '4.21.0']
# [1,mpirank:26,algo-4]<stdout>:[2023-01-24 21:28:51.056: W smdistributed/modelparallel/torch/nn/predefined_hooks.py:78] Found unsupported HuggingFace version 4.25.1 for automated tensor parallelism. HuggingFace modules will not be automatically distributed. You can use smp.tp_register_with_module API to register desired modules for tensor parallelism, or directly instantiate an smp.nn.DistributedModule. Supported HuggingFace transformers versions for automated tensor parallelism: ['4.17.0', '4.20.1', '4.21.0']
# [1,mpirank:27,algo-4]<stdout>:[2023-01-24 21:28:51.056: W smdistributed/modelparallel/torch/nn/predefined_hooks.py:78] Found unsupported HuggingFace version 4.25.1 for automated tensor parallelism. HuggingFace modules will not be automatically distributed. You can use smp.tp_register_with_module API to register desired modules for tensor parallelism, or directly instantiate an smp.nn.DistributedModule. Supported HuggingFace transformers versions for automated tensor parallelism: ['4.17.0', '4.20.1', '4.21.0']
# [1,mpirank:28,algo-4]<stdout>:[2023-01-24 21:28:51.056: W smdistributed/modelparallel/torch/nn/predefined_hooks.py:78] Found unsupported HuggingFace version 4.25.1 for automated tensor parallelism. HuggingFace modules will not be automatically distributed. You can use smp.tp_register_with_module API to register desired modules for tensor parallelism, or directly instantiate an smp.nn.DistributedModule. Supported HuggingFace transformers versions for automated tensor parallelism: ['4.17.0', '4.20.1', '4.21.0']
# [1,mpirank:29,algo-4]<stdout>:[2023-01-24 21:28:51.056: W smdistributed/modelparallel/torch/nn/predefined_hooks.py:78] Found unsupported HuggingFace version 4.25.1 for automated tensor parallelism. HuggingFace modules will not be automatically distributed. You can use smp.tp_register_with_module API to register desired modules for tensor parallelism, or directly instantiate an smp.nn.DistributedModule. Supported HuggingFace transformers versions for automated tensor parallelism: ['4.17.0', '4.20.1', '4.21.0']
# [1,mpirank:30,algo-4]<stdout>:[2023-01-24 21:28:51.056: W smdistributed/modelparallel/torch/nn/predefined_hooks.py:78] Found unsupported HuggingFace version 4.25.1 for automated tensor parallelism. HuggingFace modules will not be automatically distributed. You can use smp.tp_register_with_module API to register desired modules for tensor parallelism, or directly instantiate an smp.nn.DistributedModule. Supported HuggingFace transformers versions for automated tensor parallelism: ['4.17.0', '4.20.1', '4.21.0']
# [1,mpirank:31,algo-4]<stdout>:[2023-01-24 21:28:51.056: W smdistributed/modelparallel/torch/nn/predefined_hooks.py:78] Found unsupported HuggingFace version 4.25.1 for automated tensor parallelism. HuggingFace modules will not be automatically distributed. You can use smp.tp_register_with_module API to register desired modules for tensor parallelism, or directly instantiate an smp.nn.DistributedModule. Supported HuggingFace transformers versions for automated tensor parallelism: ['4.17.0', '4.20.1', '4.21.0']
# [1,mpirank:24,algo-4]<stdout>:[2023-01-24 21:28:51.516 algo-1:280 INFO utils.py:27] RULE_JOB_STOP_SIGNAL_FILENAME: None
# [1,mpirank:25,algo-4]<stdout>:[2023-01-24 21:28:51.516 algo-1:189 INFO utils.py:27] RULE_JOB_STOP_SIGNAL_FILENAME: None
# ...
# [1,mpirank:0,algo-1]<stdout>:[2023-01-24 21:29:21.674 algo-4:406 INFO state_store.py:115] Timestamps of different checkpoint files [('/opt/ml/checkpoints/logs', 1674595760.1303139), ('/opt/ml/checkpoints/smdebugger/collections/000000000/worker_0_collections.json', 1674595760.126314), ('/opt/ml/checkpoints/smdebugger/events/000000000000/000000000000_worker_0.tfevents', 1674595760.118314), ('/opt/ml/checkpoints/smdebugger/index/000000000/000000000000_worker_0.json', 1674595760.122314), ('/opt/ml/checkpoints/smdebugger/tensorboard/GLOBAL/000000000000_406_algo-4.tfevents', 1674595758.2303193), ('/opt/ml/checkpoints/smdebugger/tensorboard/isinf/000000000000_406_algo-4.tfevents', 1674595760.126314), ('/opt/ml/checkpoints/smdebugger/tensorboard/isnan/000000000000_406_algo-4.tfevents', 1674595760.126314), ('/opt/ml/checkpoints/smdebugger/tensorboard/l1/000000000000_406_algo-4.tfevents', 1674595760.126314), ('/opt/ml/checkpoints/smdebugger/tensorboard/l2/000000000000_406_algo-4.tfevents', 1674595760.126314), ('/opt/ml/checkpoints/smdebugger/tensorboard/max/000000000000_406_algo-4.tfevents', 1674595760.126314), ('/opt/ml/checkpoints/smdebugger/tensorboard/mean/000000000000_406_algo-4.tfevents', 1674595760.126314), ('/opt/ml/checkpoints/smdebugger/tensorboard/min/000000000000_406_algo-4.tfevents', 1674595760.126314), ('/opt/ml/checkpoints/smdebugger/tensorboard/std/000000000000_406_algo-4.tfevents', 1674595760.126314)]
# [1,mpirank:0,algo-1]<stdout>:[2023-01-24 21:29:21.675 algo-4:406 INFO state_store.py:145] sizes of different checkpoint files [('/opt/ml/checkpoints/logs', 2920), ('/opt/ml/checkpoints/smdebugger/collections/000000000/worker_0_collections.json', 40850), ('/opt/ml/checkpoints/smdebugger/events/000000000000/000000000000_worker_0.tfevents', 638083), ('/opt/ml/checkpoints/smdebugger/index/000000000/000000000000_worker_0.json', 569247), ('/opt/ml/checkpoints/smdebugger/tensorboard/GLOBAL/000000000000_406_algo-4.tfevents', 53), ('/opt/ml/checkpoints/smdebugger/tensorboard/isinf/000000000000_406_algo-4.tfevents', 64931), ('/opt/ml/checkpoints/smdebugger/tensorboard/isnan/000000000000_406_algo-4.tfevents', 64931), ('/opt/ml/checkpoints/smdebugger/tensorboard/l1/000000000000_406_algo-4.tfevents', 64931), ('/opt/ml/checkpoints/smdebugger/tensorboard/l2/000000000000_406_algo-4.tfevents', 64931), ('/opt/ml/checkpoints/smdebugger/tensorboard/max/000000000000_406_algo-4.tfevents', 64931), ('/opt/ml/checkpoints/smdebugger/tensorboard/mean/000000000000_406_algo-4.tfevents', 64931), ('/opt/ml/checkpoints/smdebugger/tensorboard/min/000000000000_406_algo-4.tfevents', 64931), ('/opt/ml/checkpoints/smdebugger/tensorboard/std/000000000000_406_algo-4.tfevents', 64931)]
# [1,mpirank:0,algo-1]<stdout>:[2023-01-24 21:29:22.477 algo-4:406 INFO state_store.py:115] Timestamps of different checkpoint files [('/opt/ml/checkpoints/logs', 1674595760.1303139), ('/opt/ml/checkpoints/smdebugger/collections/000000000/worker_0_collections.json', 1674595760.126314), ('/opt/ml/checkpoints/smdebugger/events/000000000000/000000000000_worker_0.tfevents', 1674595760.118314), ('/opt/ml/checkpoints/smdebugger/index/000000000/000000000000_worker_0.json', 1674595760.122314), ('/opt/ml/checkpoints/smdebugger/tensorboard/GLOBAL/000000000000_406_algo-4.tfevents', 1674595758.2303193), ('/opt/ml/checkpoints/smdebugger/tensorboard/isinf/000000000000_406_algo-4.tfevents', 1674595760.126314), ('/opt/ml/checkpoints/smdebugger/tensorboard/isnan/000000000000_406_algo-4.tfevents', 1674595760.126314), ('/opt/ml/checkpoints/smdebugger/tensorboard/l1/000000000000_406_algo-4.tfevents', 1674595760.126314), ('/opt/ml/checkpoints/smdebugger/tensorboard/l2/000000000000_406_algo-4.tfevents', 1674595760.126314), ('/opt/ml/checkpoints/smdebugger/tensorboard/max/000000000000_406_algo-4.tfevents', 1674595760.126314), ('/opt/ml/checkpoints/smdebugger/tensorboard/mean/000000000000_406_algo-4.tfevents', 1674595760.126314), ('/opt/ml/checkpoints/smdebugger/tensorboard/min/000000000000_406_algo-4.tfevents', 1674595760.126314), ('/opt/ml/checkpoints/smdebugger/tensorboard/std/000000000000_406_algo-4.tfevents', 1674595760.126314)]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 estimator.logs()
#
# File /opt/conda/envs/open_clip_env/lib/python3.9/site-packages/sagemaker/estimator.py:1294, in EstimatorBase.logs(self)
#    1288 def logs(self):
#    1289     """Display the logs for Estimator's training job.
#    1290
#    1291     If the output is a tty or a Jupyter cell, it will be color-coded based
#    1292     on which instance the log entry is from.
#    1293     """
# -> 1294     self.sagemaker_session.logs_for_job(self.latest_training_job.name, wait=True)
#
# File /opt/conda/envs/open_clip_env/lib/python3.9/site-packages/sagemaker/session.py:4053, in Session.logs_for_job(self, job_name, wait, poll, log_type)
#    4050 last_profiler_rule_statuses = None
#    4052 while True:
# -> 4053     _flush_log_streams(
#    4054         stream_names,
#    4055         instance_count,
#    4056         client,
#    4057         log_group,
#    4058         job_name,
#    4059         positions,
#    4060         dot,
#    4061         color_wrap,
#    4062     )
#    4063     if state == LogState.COMPLETE:
#    4064         break
#
# File /opt/conda/envs/open_clip_env/lib/python3.9/site-packages/sagemaker/session.py:5772, in _flush_log_streams(stream_names, instance_count, client, log_group, job_name, positions, dot, color_wrap)
#    5770     print("")
#    5771     dot = False
# -> 5772 for idx, event in sagemaker.logs.multi_stream_iter(
#    5773     client, log_group, stream_names, positions
#    5774 ):
#    5775     color_wrap(idx, event["message"])
#    5776     ts, count = positions[stream_names[idx]]
#
# File /opt/conda/envs/open_clip_env/lib/python3.9/site-packages/sagemaker/logs.py:122, in multi_stream_iter(client, log_group, streams, positions)
#     120     continue
#     121 try:
# --> 122     events.append(next(s))
#     123 except StopIteration:
#     124     events.append(None)
#
# File /opt/conda/envs/open_clip_env/lib/python3.9/site-packages/sagemaker/logs.py:164, in log_stream(client, log_group, stream_name, start_time, skip)
#     161 else:
#     162     token_arg = {}
# --> 164 response = client.get_log_events(
#     165     logGroupName=log_group,
#     166     logStreamName=stream_name,
#     167     startTime=start_time,
#     168     startFromHead=True,
#     169     **token_arg
#     170 )
#     171 next_token = response["nextForwardToken"]
#     172 events = response["events"]
#
# File /opt/conda/envs/open_clip_env/lib/python3.9/site-packages/botocore/client.py:530, in ClientCreator._create_api_method.<locals>._api_call(self, *args, **kwargs)
#     526     raise TypeError(
#     527         f"{py_operation_name}() only accepts keyword arguments."
#     528     )
#     529 # The "self" in this scope is referring to the BaseClient.
# --> 530 return self._make_api_call(operation_name, kwargs)
#
# File /opt/conda/envs/open_clip_env/lib/python3.9/site-packages/botocore/client.py:943, in BaseClient._make_api_call(self, operation_name, api_params)
#     941 else:
#     942     apply_request_checksum(request_dict)
# --> 943     http, parsed_response = self._make_request(
#     944         operation_model, request_dict, request_context
#     945     )
#     947 self.meta.events.emit(
#     948     'after-call.{service_id}.{operation_name}'.format(
#     949         service_id=service_id, operation_name=operation_name
#    (...)
#     954     context=request_context,
#     955 )
#     957 if http.status_code >= 300:
#
# File /opt/conda/envs/open_clip_env/lib/python3.9/site-packages/botocore/client.py:966, in BaseClient._make_request(self, operation_model, request_dict, request_context)
#     964 def _make_request(self, operation_model, request_dict, request_context):
#     965     try:
# --> 966         return self._endpoint.make_request(operation_model, request_dict)
#     967     except Exception as e:
#     968         self.meta.events.emit(
#     969             'after-call-error.{service_id}.{operation_name}'.format(
#     970                 service_id=self._service_model.service_id.hyphenize(),
#    (...)
#     974             context=request_context,
#     975         )
#
# File /opt/conda/envs/open_clip_env/lib/python3.9/site-packages/botocore/endpoint.py:119, in Endpoint.make_request(self, operation_model, request_dict)
#     113 def make_request(self, operation_model, request_dict):
#     114     logger.debug(
#     115         "Making request for %s with params: %s",
#     116         operation_model,
#     117         request_dict,
#     118     )
# --> 119     return self._send_request(request_dict, operation_model)
#
# File /opt/conda/envs/open_clip_env/lib/python3.9/site-packages/botocore/endpoint.py:199, in Endpoint._send_request(self, request_dict, operation_model)
#     197 self._update_retries_context(context, attempts)
#     198 request = self.create_request(request_dict, operation_model)
# --> 199 success_response, exception = self._get_response(
#     200     request, operation_model, context
#     201 )
#     202 while self._needs_retry(
#     203     attempts,
#     204     operation_model,
#    (...)
#     207     exception,
#     208 ):
#     209     attempts += 1
#
# File /opt/conda/envs/open_clip_env/lib/python3.9/site-packages/botocore/endpoint.py:241, in Endpoint._get_response(self, request, operation_model, context)
#     235 def _get_response(self, request, operation_model, context):
#     236     # This will return a tuple of (success_response, exception)
#     237     # and success_response is itself a tuple of
#     238     # (http_response, parsed_dict).
#     239     # If an exception occurs then the success_response is None.
#     240     # If no exception occurs then exception is None.
# --> 241     success_response, exception = self._do_get_response(
#     242         request, operation_model, context
#     243     )
#     244     kwargs_to_emit = {
#     245         'response_dict': None,
#     246         'parsed_response': None,
#     247         'context': context,
#     248         'exception': exception,
#     249     }
#     250     if success_response is not None:
#
# File /opt/conda/envs/open_clip_env/lib/python3.9/site-packages/botocore/endpoint.py:281, in Endpoint._do_get_response(self, request, operation_model, context)
#     279     http_response = first_non_none_response(responses)
#     280     if http_response is None:
# --> 281         http_response = self._send(request)
#     282 except HTTPClientError as e:
#     283     return (None, e)
#
# File /opt/conda/envs/open_clip_env/lib/python3.9/site-packages/botocore/endpoint.py:377, in Endpoint._send(self, request)
#     376 def _send(self, request):
# --> 377     return self.http_session.send(request)
#
# File /opt/conda/envs/open_clip_env/lib/python3.9/site-packages/botocore/httpsession.py:455, in URLLib3Session.send(self, request)
#     452     conn.proxy_headers['host'] = host
#     454 request_target = self._get_request_target(request.url, proxy_url)
# --> 455 urllib_response = conn.urlopen(
#     456     method=request.method,
#     457     url=request_target,
#     458     body=request.body,
#     459     headers=request.headers,
#     460     retries=Retry(False),
#     461     assert_same_host=False,
#     462     preload_content=False,
#     463     decode_content=False,
#     464     chunked=self._chunked(request.headers),
#     465 )
#     467 http_response = botocore.awsrequest.AWSResponse(
#     468     request.url,
#     469     urllib_response.status,
#     470     urllib_response.headers,
#     471     urllib_response,
#     472 )
#     474 if not request.stream_output:
#     475     # Cause the raw stream to be exhausted immediately. We do it
#     476     # this way instead of using preload_content because
#     477     # preload_content will never buffer chunked responses
#
# File /opt/conda/envs/open_clip_env/lib/python3.9/site-packages/urllib3/connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     700     self._prepare_proxy(conn)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
#     717 response_conn = conn if not release_conn else None
#
# File /opt/conda/envs/open_clip_env/lib/python3.9/site-packages/urllib3/connectionpool.py:449, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     444             httplib_response = conn.getresponse()
#     445         except BaseException as e:
#     446             # Remove the TypeError from the exception chain in
#     447             # Python 3 (including for exceptions like SystemExit).
#     448             # Otherwise it looks like a bug in the code.
# --> 449             six.raise_from(e, None)
#     450 except (SocketTimeout, BaseSSLError, SocketError) as e:
#     451     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File <string>:3, in raise_from(value, from_value)
#
# File /opt/conda/envs/open_clip_env/lib/python3.9/site-packages/urllib3/connectionpool.py:444, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     441 except TypeError:
#     442     # Python 3
#     443     try:
# --> 444         httplib_response = conn.getresponse()
#     445     except BaseException as e:
#     446         # Remove the TypeError from the exception chain in
#     447         # Python 3 (including for exceptions like SystemExit).
#     448         # Otherwise it looks like a bug in the code.
#     449         six.raise_from(e, None)
#
# File /opt/conda/envs/open_clip_env/lib/python3.9/http/client.py:1377, in HTTPConnection.getresponse(self)
#    1375 try:
#    1376     try:
# -> 1377         response.begin()
#    1378     except ConnectionError:
#    1379         self.close()
#
# File /opt/conda/envs/open_clip_env/lib/python3.9/http/client.py:320, in HTTPResponse.begin(self)
#     318 # read until we get a non-100 response
#     319 while True:
# --> 320     version, status, reason = self._read_status()
#     321     if status != CONTINUE:
#     322         break
#
# File /opt/conda/envs/open_clip_env/lib/python3.9/http/client.py:281, in HTTPResponse._read_status(self)
#     280 def _read_status(self):
# --> 281     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     282     if len(line) > _MAXLINE:
#     283         raise LineTooLong("status line")
#
# File /opt/conda/envs/open_clip_env/lib/python3.9/socket.py:704, in SocketIO.readinto(self, b)
#     702 while True:
#     703     try:
# --> 704         return self._sock.recv_into(b)
#     705     except timeout:
#     706         self._timeout_occurred = True
#
# File /opt/conda/envs/open_clip_env/lib/python3.9/ssl.py:1242, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1238     if flags != 0:
#    1239         raise ValueError(
#    1240           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1241           self.__class__)
# -> 1242     return self.read(nbytes, buffer)
#    1243 else:
#    1244     return super().recv_into(buffer, nbytes, flags)
#
# File /opt/conda/envs/open_clip_env/lib/python3.9/ssl.py:1100, in SSLSocket.read(self, len, buffer)
#    1098 try:
#    1099     if buffer is not None:
# -> 1100         return self._sslobj.read(len, buffer)
#    1101     else:
#    1102         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
estimator.checkpoint_s3_uri
# Out:
# 's3://jbsnyder-sagemaker-us-west-2/sagemaker-output/24-01-2023/openclip-scaling-24-01-2023-21-17-32/training-checkpoints'

# %%
import numpy as np

# %%
np.sqrt(1e-10)
# Out:
# 1e-05

# %%
import torch

# %%
torch.op
